# %%
import os
import shutil

# %%
src_dir = 'Dataset_BUSI_with_GT'
dst_dir = 'BUSI_division'
images_dir = os.path.join(dst_dir, 'images')
masks_dir = os.path.join(dst_dir, 'masks')

# Cria as pastas de destino
os.makedirs(images_dir, exist_ok=True)
os.makedirs(masks_dir, exist_ok=True)

# %%
# Percorre todo o diretório original
count_images = 0
count_masks = 0

for root, _, files in os.walk(src_dir):
    for file in files:
        if file.endswith('.png') or file.endswith('.jpg'):
            src_path = os.path.join(root, file)
            
            # Se tiver "_mask" no nome, vai pra pasta masks/, senão vai pra images/
            if '_mask' in file:
                dst_path = os.path.join(masks_dir, file)
                count_masks += 1
            else:
                dst_path = os.path.join(images_dir, file)
                count_images += 1
                
            shutil.copy(src_path, dst_path)

print(f"Organização concluída!")
print(f"Imagens originais movidas: {count_images}")
print(f"Máscaras movidas: {count_masks}")

# %%
from ultralytics.data.converter import convert_segment_masks_to_yolo_seg

# The classes here is the total classes in the dataset.
# for COCO dataset we have 80 classes.
convert_segment_masks_to_yolo_seg(masks_dir="BUSI_division/masks", output_dir="BUSI_division/labels", classes=3)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/home/giovannadefigueiredobrito/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Processing BUSI_division/masks/benign (1)_mask.png imgsz = 471 x 562
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (1)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (1)_mask.txt imgsz = 471 x 562
# Processing BUSI_division/masks/benign (10)_mask.png imgsz = 585 x 683
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (10)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (10)_mask.txt imgsz = 585 x 683
# Processing BUSI_division/masks/benign (100)_mask.png imgsz = 473 x 323
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (100)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (100)_mask.txt imgsz = 473 x 323
# Processing BUSI_division/masks/benign (100)_mask_1.png imgsz = 473 x 323
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (100)_mask_1.png, skipping.
# Processed and stored at BUSI_division/labels/benign (100)_mask_1.txt imgsz = 473 x 323
# Processing BUSI_division/masks/benign (101)_mask.png imgsz = 473 x 563
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (101)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (101)_mask.txt imgsz = 473 x 563
# Processing BUSI_division/masks/benign (102)_mask.png imgsz = 610 x 634
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (102)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (102)_mask.txt imgsz = 610 x 634
# Processing BUSI_division/masks/benign (103)_mask.png imgsz = 585 x 766
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (103)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (103)_mask.txt imgsz = 585 x 766
# Processing BUSI_division/masks/benign (104)_mask.png imgsz = 578 x 777
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (104)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (104)_mask.txt imgsz = 578 x 777
# Processing BUSI_division/masks/benign (105)_mask.png imgsz = 581 x 882
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (105)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (105)_mask.txt imgsz = 581 x 882
# Processing BUSI_division/masks/benign (106)_mask.png imgsz = 716 x 808
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (106)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (106)_mask.txt imgsz = 716 x 808
# Processing BUSI_division/masks/benign (107)_mask.png imgsz = 616 x 759
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (107)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (107)_mask.txt imgsz = 616 x 759
# Processing BUSI_division/masks/benign (108)_mask.png imgsz = 582 x 769
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (108)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (108)_mask.txt imgsz = 582 x 769
# Processing BUSI_division/masks/benign (109)_mask.png imgsz = 470 x 562
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (109)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (109)_mask.txt imgsz = 470 x 562
# Processing BUSI_division/masks/benign (11)_mask.png imgsz = 587 x 689
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (11)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (11)_mask.txt imgsz = 587 x 689
# Processing BUSI_division/masks/benign (110)_mask.png imgsz = 468 x 555
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (110)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (110)_mask.txt imgsz = 468 x 555
# Processing BUSI_division/masks/benign (111)_mask.png imgsz = 477 x 315
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (111)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (111)_mask.txt imgsz = 477 x 315
# Processing BUSI_division/masks/benign (112)_mask.png imgsz = 612 x 652
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (112)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (112)_mask.txt imgsz = 612 x 652
# Processing BUSI_division/masks/benign (113)_mask.png imgsz = 695 x 810
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (113)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (113)_mask.txt imgsz = 695 x 810
# Processing BUSI_division/masks/benign (114)_mask.png imgsz = 575 x 757
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (114)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (114)_mask.txt imgsz = 575 x 757
# Processing BUSI_division/masks/benign (115)_mask.png imgsz = 469 x 554
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (115)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (115)_mask.txt imgsz = 469 x 554
# Processing BUSI_division/masks/benign (116)_mask.png imgsz = 588 x 766
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (116)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (116)_mask.txt imgsz = 588 x 766
# Processing BUSI_division/masks/benign (117)_mask.png imgsz = 688 x 806
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (117)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (117)_mask.txt imgsz = 688 x 806
# Processing BUSI_division/masks/benign (118)_mask.png imgsz = 620 x 653
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (118)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (118)_mask.txt imgsz = 620 x 653
# Processing BUSI_division/masks/benign (119)_mask.png imgsz = 585 x 762
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (119)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (119)_mask.txt imgsz = 585 x 762
# Processing BUSI_division/masks/benign (12)_mask.png imgsz = 571 x 678
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (12)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (12)_mask.txt imgsz = 571 x 678
# Processing BUSI_division/masks/benign (120)_mask.png imgsz = 695 x 808
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (120)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (120)_mask.txt imgsz = 695 x 808
# Processing BUSI_division/masks/benign (121)_mask.png imgsz = 610 x 646
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (121)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (121)_mask.txt imgsz = 610 x 646
# Processing BUSI_division/masks/benign (122)_mask.png imgsz = 577 x 774
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (122)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (122)_mask.txt imgsz = 577 x 774
# Processing BUSI_division/masks/benign (123)_mask.png imgsz = 610 x 648
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (123)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (123)_mask.txt imgsz = 610 x 648
# Processing BUSI_division/masks/benign (124)_mask.png imgsz = 614 x 645
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (124)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (124)_mask.txt imgsz = 614 x 645
# Processing BUSI_division/masks/benign (125)_mask.png imgsz = 578 x 756
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (125)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (125)_mask.txt imgsz = 578 x 756
# Processing BUSI_division/masks/benign (126)_mask.png imgsz = 570 x 771
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (126)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (126)_mask.txt imgsz = 570 x 771
# Processing BUSI_division/masks/benign (127)_mask.png imgsz = 476 x 558
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (127)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (127)_mask.txt imgsz = 476 x 558
# Processing BUSI_division/masks/benign (128)_mask.png imgsz = 475 x 549
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (128)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (128)_mask.txt imgsz = 475 x 549
# Processing BUSI_division/masks/benign (129)_mask.png imgsz = 587 x 775
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (129)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (129)_mask.txt imgsz = 587 x 775
# Processing BUSI_division/masks/benign (13)_mask.png imgsz = 571 x 678
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (13)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (13)_mask.txt imgsz = 571 x 678
# Processing BUSI_division/masks/benign (130)_mask.png imgsz = 474 x 558
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (130)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (130)_mask.txt imgsz = 474 x 558
# Processing BUSI_division/masks/benign (131)_mask.png imgsz = 435 x 587
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (131)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (131)_mask.txt imgsz = 435 x 587
# Processing BUSI_division/masks/benign (132)_mask.png imgsz = 483 x 552
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (132)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (132)_mask.txt imgsz = 483 x 552
# Processing BUSI_division/masks/benign (133)_mask.png imgsz = 342 x 369
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (133)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (133)_mask.txt imgsz = 342 x 369
# Processing BUSI_division/masks/benign (134)_mask.png imgsz = 345 x 378
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (134)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (134)_mask.txt imgsz = 345 x 378
# Processing BUSI_division/masks/benign (135)_mask.png imgsz = 582 x 776
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (135)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (135)_mask.txt imgsz = 582 x 776
# Processing BUSI_division/masks/benign (136)_mask.png imgsz = 581 x 886
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (136)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (136)_mask.txt imgsz = 581 x 886
# Processing BUSI_division/masks/benign (137)_mask.png imgsz = 578 x 777
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (137)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (137)_mask.txt imgsz = 578 x 777
# Processing BUSI_division/masks/benign (138)_mask.png imgsz = 600 x 766
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (138)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (138)_mask.txt imgsz = 600 x 766
# Processing BUSI_division/masks/benign (139)_mask.png imgsz = 468 x 563
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (139)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (139)_mask.txt imgsz = 468 x 563
# Processing BUSI_division/masks/benign (14)_mask.png imgsz = 531 x 699
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (14)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (14)_mask.txt imgsz = 531 x 699
# Processing BUSI_division/masks/benign (140)_mask.png imgsz = 591 x 452
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (140)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (140)_mask.txt imgsz = 591 x 452
# Processing BUSI_division/masks/benign (141)_mask.png imgsz = 471 x 567
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (141)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (141)_mask.txt imgsz = 471 x 567
# Processing BUSI_division/masks/benign (142)_mask.png imgsz = 582 x 785
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (142)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (142)_mask.txt imgsz = 582 x 785
# Processing BUSI_division/masks/benign (143)_mask.png imgsz = 467 x 554
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (143)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (143)_mask.txt imgsz = 467 x 554
# Processing BUSI_division/masks/benign (144)_mask.png imgsz = 580 x 770
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (144)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (144)_mask.txt imgsz = 580 x 770
# Processing BUSI_division/masks/benign (145)_mask.png imgsz = 574 x 779
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (145)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (145)_mask.txt imgsz = 574 x 779
# Processing BUSI_division/masks/benign (146)_mask.png imgsz = 594 x 449
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (146)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (146)_mask.txt imgsz = 594 x 449
# Processing BUSI_division/masks/benign (147)_mask.png imgsz = 463 x 564
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (147)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (147)_mask.txt imgsz = 463 x 564
# Processing BUSI_division/masks/benign (148)_mask.png imgsz = 463 x 567
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (148)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (148)_mask.txt imgsz = 463 x 567
# Processing BUSI_division/masks/benign (149)_mask.png imgsz = 468 x 557
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (149)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (149)_mask.txt imgsz = 468 x 557
# Processing BUSI_division/masks/benign (15)_mask.png imgsz = 526 x 701
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (15)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (15)_mask.txt imgsz = 526 x 701
# Processing BUSI_division/masks/benign (150)_mask.png imgsz = 570 x 671
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (150)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (150)_mask.txt imgsz = 570 x 671
# Processing BUSI_division/masks/benign (151)_mask.png imgsz = 469 x 560
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (151)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (151)_mask.txt imgsz = 469 x 560
# Processing BUSI_division/masks/benign (152)_mask.png imgsz = 471 x 555
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (152)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (152)_mask.txt imgsz = 471 x 555
# Processing BUSI_division/masks/benign (153)_mask.png imgsz = 574 x 772
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (153)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (153)_mask.txt imgsz = 574 x 772
# Processing BUSI_division/masks/benign (154)_mask.png imgsz = 464 x 556
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (154)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (154)_mask.txt imgsz = 464 x 556
# Processing BUSI_division/masks/benign (155)_mask.png imgsz = 583 x 783
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (155)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (155)_mask.txt imgsz = 583 x 783
# Processing BUSI_division/masks/benign (156)_mask.png imgsz = 581 x 887
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (156)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (156)_mask.txt imgsz = 581 x 887
# Processing BUSI_division/masks/benign (157)_mask.png imgsz = 465 x 567
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (157)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (157)_mask.txt imgsz = 465 x 567
# Processing BUSI_division/masks/benign (158)_mask.png imgsz = 464 x 556
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (158)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (158)_mask.txt imgsz = 464 x 556
# Processing BUSI_division/masks/benign (159)_mask.png imgsz = 574 x 696
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (159)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (159)_mask.txt imgsz = 574 x 696
# Processing BUSI_division/masks/benign (16)_mask.png imgsz = 462 x 558
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (16)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (16)_mask.txt imgsz = 462 x 558
# Processing BUSI_division/masks/benign (160)_mask.png imgsz = 585 x 624
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (160)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (160)_mask.txt imgsz = 585 x 624
# Processing BUSI_division/masks/benign (161)_mask.png imgsz = 463 x 568
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (161)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (161)_mask.txt imgsz = 463 x 568
# Processing BUSI_division/masks/benign (162)_mask.png imgsz = 470 x 549
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (162)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (162)_mask.txt imgsz = 470 x 549
# Processing BUSI_division/masks/benign (163)_mask.png imgsz = 576 x 779
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (163)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (163)_mask.txt imgsz = 576 x 779
# Processing BUSI_division/masks/benign (163)_mask_1.png imgsz = 576 x 779
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (163)_mask_1.png, skipping.
# Processed and stored at BUSI_division/labels/benign (163)_mask_1.txt imgsz = 576 x 779
# Processing BUSI_division/masks/benign (164)_mask.png imgsz = 470 x 560
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (164)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (164)_mask.txt imgsz = 470 x 560
# Processing BUSI_division/masks/benign (165)_mask.png imgsz = 464 x 558
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (165)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (165)_mask.txt imgsz = 464 x 558
# Processing BUSI_division/masks/benign (166)_mask.png imgsz = 471 x 555
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (166)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (166)_mask.txt imgsz = 471 x 555
# Processing BUSI_division/masks/benign (167)_mask.png imgsz = 463 x 566
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (167)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (167)_mask.txt imgsz = 463 x 566
# Processing BUSI_division/masks/benign (168)_mask.png imgsz = 471 x 557
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (168)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (168)_mask.txt imgsz = 471 x 557
# Processing BUSI_division/masks/benign (169)_mask.png imgsz = 469 x 561
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (169)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (169)_mask.txt imgsz = 469 x 561
# Processing BUSI_division/masks/benign (17)_mask.png imgsz = 463 x 558
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (17)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (17)_mask.txt imgsz = 463 x 558
# Processing BUSI_division/masks/benign (170)_mask.png imgsz = 468 x 564
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (170)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (170)_mask.txt imgsz = 468 x 564
# Processing BUSI_division/masks/benign (171)_mask.png imgsz = 463 x 566
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (171)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (171)_mask.txt imgsz = 463 x 566
# Processing BUSI_division/masks/benign (172)_mask.png imgsz = 589 x 619
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (172)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (172)_mask.txt imgsz = 589 x 619
# Processing BUSI_division/masks/benign (173)_mask.png imgsz = 573 x 726
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (173)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (173)_mask.txt imgsz = 573 x 726
# Processing BUSI_division/masks/benign (173)_mask_1.png imgsz = 573 x 726
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (173)_mask_1.png, skipping.
# Processed and stored at BUSI_division/labels/benign (173)_mask_1.txt imgsz = 573 x 726
# Processing BUSI_division/masks/benign (174)_mask.png imgsz = 490 x 556
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (174)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (174)_mask.txt imgsz = 490 x 556
# Processing BUSI_division/masks/benign (175)_mask.png imgsz = 573 x 765
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (175)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (175)_mask.txt imgsz = 573 x 765
# Processing BUSI_division/masks/benign (176)_mask.png imgsz = 487 x 715
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (176)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (176)_mask.txt imgsz = 487 x 715
# Processing BUSI_division/masks/benign (177)_mask.png imgsz = 470 x 562
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (177)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (177)_mask.txt imgsz = 470 x 562
# Processing BUSI_division/masks/benign (178)_mask.png imgsz = 576 x 772
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (178)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (178)_mask.txt imgsz = 576 x 772
# Processing BUSI_division/masks/benign (179)_mask.png imgsz = 468 x 422
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (179)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (179)_mask.txt imgsz = 468 x 422
# Processing BUSI_division/masks/benign (18)_mask.png imgsz = 469 x 564
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (18)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (18)_mask.txt imgsz = 469 x 564
# Processing BUSI_division/masks/benign (180)_mask.png imgsz = 600 x 763
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (180)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (180)_mask.txt imgsz = 600 x 763
# Processing BUSI_division/masks/benign (181)_mask.png imgsz = 455 x 733
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (181)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (181)_mask.txt imgsz = 455 x 733
# Processing BUSI_division/masks/benign (181)_mask_1.png imgsz = 455 x 733
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (181)_mask_1.png, skipping.
# Processed and stored at BUSI_division/labels/benign (181)_mask_1.txt imgsz = 455 x 733
# Processing BUSI_division/masks/benign (182)_mask.png imgsz = 463 x 555
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (182)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (182)_mask.txt imgsz = 463 x 555
# Processing BUSI_division/masks/benign (183)_mask.png imgsz = 683 x 916
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (183)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (183)_mask.txt imgsz = 683 x 916
# Processing BUSI_division/masks/benign (184)_mask.png imgsz = 487 x 349
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (184)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (184)_mask.txt imgsz = 487 x 349
# Processing BUSI_division/masks/benign (185)_mask.png imgsz = 592 x 752
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (185)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (185)_mask.txt imgsz = 592 x 752
# Processing BUSI_division/masks/benign (186)_mask.png imgsz = 574 x 741
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (186)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (186)_mask.txt imgsz = 574 x 741
# Processing BUSI_division/masks/benign (187)_mask.png imgsz = 574 x 730
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (187)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (187)_mask.txt imgsz = 574 x 730
# Processing BUSI_division/masks/benign (188)_mask.png imgsz = 600 x 655
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (188)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (188)_mask.txt imgsz = 600 x 655
# Processing BUSI_division/masks/benign (189)_mask.png imgsz = 465 x 544
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (189)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (189)_mask.txt imgsz = 465 x 544
# Processing BUSI_division/masks/benign (19)_mask.png imgsz = 572 x 663
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (19)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (19)_mask.txt imgsz = 572 x 663
# Processing BUSI_division/masks/benign (190)_mask.png imgsz = 470 x 734
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (190)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (190)_mask.txt imgsz = 470 x 734
# Processing BUSI_division/masks/benign (191)_mask.png imgsz = 463 x 549
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (191)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (191)_mask.txt imgsz = 463 x 549
# Processing BUSI_division/masks/benign (192)_mask.png imgsz = 474 x 557
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (192)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (192)_mask.txt imgsz = 474 x 557
# Processing BUSI_division/masks/benign (193)_mask.png imgsz = 580 x 754
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (193)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (193)_mask.txt imgsz = 580 x 754
# Processing BUSI_division/masks/benign (194)_mask.png imgsz = 492 x 711
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (194)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (194)_mask.txt imgsz = 492 x 711
# Processing BUSI_division/masks/benign (195)_mask.png imgsz = 611 x 729
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (195)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (195)_mask.txt imgsz = 611 x 729
# Processing BUSI_division/masks/benign (195)_mask_1.png imgsz = 611 x 729
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (195)_mask_1.png, skipping.
# Processed and stored at BUSI_division/labels/benign (195)_mask_1.txt imgsz = 611 x 729
# Processing BUSI_division/masks/benign (195)_mask_2.png imgsz = 611 x 729
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (195)_mask_2.png, skipping.
# Processed and stored at BUSI_division/labels/benign (195)_mask_2.txt imgsz = 611 x 729
# Processing BUSI_division/masks/benign (196)_mask.png imgsz = 580 x 766
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (196)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (196)_mask.txt imgsz = 580 x 766
# Processing BUSI_division/masks/benign (197)_mask.png imgsz = 465 x 547
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (197)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (197)_mask.txt imgsz = 465 x 547
# Processing BUSI_division/masks/benign (198)_mask.png imgsz = 571 x 759
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (198)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (198)_mask.txt imgsz = 571 x 759
# Processing BUSI_division/masks/benign (199)_mask.png imgsz = 473 x 556
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (199)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (199)_mask.txt imgsz = 473 x 556
# Processing BUSI_division/masks/benign (2)_mask.png imgsz = 473 x 557
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (2)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (2)_mask.txt imgsz = 473 x 557
# Processing BUSI_division/masks/benign (20)_mask.png imgsz = 473 x 319
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (20)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (20)_mask.txt imgsz = 473 x 319
# Processing BUSI_division/masks/benign (200)_mask.png imgsz = 473 x 554
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (200)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (200)_mask.txt imgsz = 473 x 554
# Processing BUSI_division/masks/benign (201)_mask.png imgsz = 474 x 556
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (201)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (201)_mask.txt imgsz = 474 x 556
# Processing BUSI_division/masks/benign (202)_mask.png imgsz = 469 x 552
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (202)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (202)_mask.txt imgsz = 469 x 552
# Processing BUSI_division/masks/benign (203)_mask.png imgsz = 471 x 569
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (203)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (203)_mask.txt imgsz = 471 x 569
# Processing BUSI_division/masks/benign (204)_mask.png imgsz = 476 x 560
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (204)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (204)_mask.txt imgsz = 476 x 560
# Processing BUSI_division/masks/benign (205)_mask.png imgsz = 477 x 557
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (205)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (205)_mask.txt imgsz = 477 x 557
# Processing BUSI_division/masks/benign (206)_mask.png imgsz = 485 x 569
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (206)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (206)_mask.txt imgsz = 485 x 569
# Processing BUSI_division/masks/benign (207)_mask.png imgsz = 481 x 562
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (207)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (207)_mask.txt imgsz = 481 x 562
# Processing BUSI_division/masks/benign (208)_mask.png imgsz = 479 x 562
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (208)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (208)_mask.txt imgsz = 479 x 562
# Processing BUSI_division/masks/benign (209)_mask.png imgsz = 477 x 558
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (209)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (209)_mask.txt imgsz = 477 x 558
# Processing BUSI_division/masks/benign (21)_mask.png imgsz = 451 x 558
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (21)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (21)_mask.txt imgsz = 451 x 558
# Processing BUSI_division/masks/benign (210)_mask.png imgsz = 471 x 563
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (210)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (210)_mask.txt imgsz = 471 x 563
# Processing BUSI_division/masks/benign (211)_mask.png imgsz = 465 x 557
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (211)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (211)_mask.txt imgsz = 465 x 557
# Processing BUSI_division/masks/benign (212)_mask.png imgsz = 469 x 558
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (212)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (212)_mask.txt imgsz = 469 x 558
# Processing BUSI_division/masks/benign (213)_mask.png imgsz = 486 x 573
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (213)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (213)_mask.txt imgsz = 486 x 573
# Processing BUSI_division/masks/benign (214)_mask.png imgsz = 396 x 602
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (214)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (214)_mask.txt imgsz = 396 x 602
# Processing BUSI_division/masks/benign (215)_mask.png imgsz = 396 x 600
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (215)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (215)_mask.txt imgsz = 396 x 600
# Processing BUSI_division/masks/benign (216)_mask.png imgsz = 386 x 646
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (216)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (216)_mask.txt imgsz = 386 x 646
# Processing BUSI_division/masks/benign (217)_mask.png imgsz = 396 x 603
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (217)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (217)_mask.txt imgsz = 396 x 603
# Processing BUSI_division/masks/benign (218)_mask.png imgsz = 396 x 602
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (218)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (218)_mask.txt imgsz = 396 x 602
# Processing BUSI_division/masks/benign (219)_mask.png imgsz = 396 x 608
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (219)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (219)_mask.txt imgsz = 396 x 608
# Processing BUSI_division/masks/benign (22)_mask.png imgsz = 463 x 562
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (22)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (22)_mask.txt imgsz = 463 x 562
# Processing BUSI_division/masks/benign (220)_mask.png imgsz = 396 x 609
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (220)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (220)_mask.txt imgsz = 396 x 609
# Processing BUSI_division/masks/benign (221)_mask.png imgsz = 394 x 610
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (221)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (221)_mask.txt imgsz = 394 x 610
# Processing BUSI_division/masks/benign (222)_mask.png imgsz = 392 x 605
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (222)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (222)_mask.txt imgsz = 392 x 605
# Processing BUSI_division/masks/benign (223)_mask.png imgsz = 465 x 562
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (223)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (223)_mask.txt imgsz = 465 x 562
# Processing BUSI_division/masks/benign (224)_mask.png imgsz = 469 x 568
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (224)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (224)_mask.txt imgsz = 469 x 568
# Processing BUSI_division/masks/benign (225)_mask.png imgsz = 473 x 558
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (225)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (225)_mask.txt imgsz = 473 x 558
# Processing BUSI_division/masks/benign (226)_mask.png imgsz = 469 x 555
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (226)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (226)_mask.txt imgsz = 469 x 555
# Processing BUSI_division/masks/benign (227)_mask.png imgsz = 468 x 567
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (227)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (227)_mask.txt imgsz = 468 x 567
# Processing BUSI_division/masks/benign (228)_mask.png imgsz = 469 x 563
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (228)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (228)_mask.txt imgsz = 469 x 563
# Processing BUSI_division/masks/benign (229)_mask.png imgsz = 470 x 564
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (229)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (229)_mask.txt imgsz = 470 x 564
# Processing BUSI_division/masks/benign (23)_mask.png imgsz = 583 x 779
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (23)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (23)_mask.txt imgsz = 583 x 779
# Processing BUSI_division/masks/benign (230)_mask.png imgsz = 470 x 566
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (230)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (230)_mask.txt imgsz = 470 x 566
# Processing BUSI_division/masks/benign (231)_mask.png imgsz = 472 x 561
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (231)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (231)_mask.txt imgsz = 472 x 561
# Processing BUSI_division/masks/benign (232)_mask.png imgsz = 469 x 562
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (232)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (232)_mask.txt imgsz = 469 x 562
# Processing BUSI_division/masks/benign (233)_mask.png imgsz = 471 x 557
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (233)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (233)_mask.txt imgsz = 471 x 557
# Processing BUSI_division/masks/benign (234)_mask.png imgsz = 469 x 562
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (234)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (234)_mask.txt imgsz = 469 x 562
# Processing BUSI_division/masks/benign (235)_mask.png imgsz = 468 x 560
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (235)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (235)_mask.txt imgsz = 468 x 560
# Processing BUSI_division/masks/benign (236)_mask.png imgsz = 469 x 566
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (236)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (236)_mask.txt imgsz = 469 x 566
# Processing BUSI_division/masks/benign (237)_mask.png imgsz = 473 x 558
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (237)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (237)_mask.txt imgsz = 473 x 558
# Processing BUSI_division/masks/benign (238)_mask.png imgsz = 469 x 556
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (238)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (238)_mask.txt imgsz = 469 x 556
# Processing BUSI_division/masks/benign (239)_mask.png imgsz = 473 x 560
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (239)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (239)_mask.txt imgsz = 473 x 560
# Processing BUSI_division/masks/benign (24)_mask.png imgsz = 467 x 556
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (24)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (24)_mask.txt imgsz = 467 x 556
# Processing BUSI_division/masks/benign (240)_mask.png imgsz = 473 x 556
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (240)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (240)_mask.txt imgsz = 473 x 556
# Processing BUSI_division/masks/benign (241)_mask.png imgsz = 471 x 562
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (241)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (241)_mask.txt imgsz = 471 x 562
# Processing BUSI_division/masks/benign (242)_mask.png imgsz = 474 x 556
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (242)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (242)_mask.txt imgsz = 474 x 556
# Processing BUSI_division/masks/benign (243)_mask.png imgsz = 473 x 561
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (243)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (243)_mask.txt imgsz = 473 x 561
# Processing BUSI_division/masks/benign (244)_mask.png imgsz = 475 x 561
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (244)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (244)_mask.txt imgsz = 475 x 561
# Processing BUSI_division/masks/benign (245)_mask.png imgsz = 465 x 560
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (245)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (245)_mask.txt imgsz = 465 x 560
# Processing BUSI_division/masks/benign (246)_mask.png imgsz = 331 x 526
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (246)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (246)_mask.txt imgsz = 331 x 526
# Processing BUSI_division/masks/benign (247)_mask.png imgsz = 396 x 469
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (247)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (247)_mask.txt imgsz = 396 x 469
# Processing BUSI_division/masks/benign (248)_mask.png imgsz = 385 x 472
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (248)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (248)_mask.txt imgsz = 385 x 472
# Processing BUSI_division/masks/benign (249)_mask.png imgsz = 395 x 465
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (249)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (249)_mask.txt imgsz = 395 x 465
# Processing BUSI_division/masks/benign (25)_mask.png imgsz = 583 x 770
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (25)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (25)_mask.txt imgsz = 583 x 770
# Processing BUSI_division/masks/benign (25)_mask_1.png imgsz = 583 x 770
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (25)_mask_1.png, skipping.
# Processed and stored at BUSI_division/labels/benign (25)_mask_1.txt imgsz = 583 x 770
# Processing BUSI_division/masks/benign (250)_mask.png imgsz = 394 x 469
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (250)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (250)_mask.txt imgsz = 394 x 469
# Processing BUSI_division/masks/benign (251)_mask.png imgsz = 387 x 467
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (251)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (251)_mask.txt imgsz = 387 x 467
# Processing BUSI_division/masks/benign (252)_mask.png imgsz = 398 x 473
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (252)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (252)_mask.txt imgsz = 398 x 473
# Processing BUSI_division/masks/benign (253)_mask.png imgsz = 383 x 463
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (253)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (253)_mask.txt imgsz = 383 x 463
# Processing BUSI_division/masks/benign (254)_mask.png imgsz = 389 x 473
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (254)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (254)_mask.txt imgsz = 389 x 473
# Processing BUSI_division/masks/benign (255)_mask.png imgsz = 389 x 473
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (255)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (255)_mask.txt imgsz = 389 x 473
# Processing BUSI_division/masks/benign (256)_mask.png imgsz = 395 x 469
# WARNING ⚠️ Unknown class for pixel value 255 in file BUSI_division/masks/benign (256)_mask.png, skipping.
# Processed and stored at BUSI_division/labels/benign (256)_mask.txt imgsz = 395 x 469
# ...
# Processed and stored at BUSI_division/labels/normal (125)_mask.txt imgsz = 471 x 558
# Processing BUSI_division/masks/normal (126)_mask.png imgsz = 601 x 765
# Processed and stored at BUSI_division/labels/normal (126)_mask.txt imgsz = 601 x 765
# Processing BUSI_division/masks/normal (127)_mask.png imgsz = 467 x 555
# Processed and stored at BUSI_division/labels/normal (127)_mask.txt imgsz = 467 x 555
# Processing BUSI_division/masks/normal (128)_mask.png imgsz = 596 x 622
# Processed and stored at BUSI_division/labels/normal (128)_mask.txt imgsz = 596 x 622
# Processing BUSI_division/masks/normal (129)_mask.png imgsz = 684 x 617
# Processed and stored at BUSI_division/labels/normal (129)_mask.txt imgsz = 684 x 617
# Processing BUSI_division/masks/normal (13)_mask.png imgsz = 574 x 779
# Processed and stored at BUSI_division/labels/normal (13)_mask.txt imgsz = 574 x 779
# Processing BUSI_division/masks/normal (130)_mask.png imgsz = 477 x 739
# Processed and stored at BUSI_division/labels/normal (130)_mask.txt imgsz = 477 x 739
# Processing BUSI_division/masks/normal (131)_mask.png imgsz = 574 x 669
# Processed and stored at BUSI_division/labels/normal (131)_mask.txt imgsz = 574 x 669
# Processing BUSI_division/masks/normal (132)_mask.png imgsz = 700 x 857
# Processed and stored at BUSI_division/labels/normal (132)_mask.txt imgsz = 700 x 857
# Processing BUSI_division/masks/normal (133)_mask.png imgsz = 471 x 560
# Processed and stored at BUSI_division/labels/normal (133)_mask.txt imgsz = 471 x 560
# Processing BUSI_division/masks/normal (14)_mask.png imgsz = 581 x 765
# Processed and stored at BUSI_division/labels/normal (14)_mask.txt imgsz = 581 x 765
# Processing BUSI_division/masks/normal (15)_mask.png imgsz = 464 x 554
# Processed and stored at BUSI_division/labels/normal (15)_mask.txt imgsz = 464 x 554
# Processing BUSI_division/masks/normal (16)_mask.png imgsz = 464 x 566
# Processed and stored at BUSI_division/labels/normal (16)_mask.txt imgsz = 464 x 566
# Processing BUSI_division/masks/normal (17)_mask.png imgsz = 465 x 560
# Processed and stored at BUSI_division/labels/normal (17)_mask.txt imgsz = 465 x 560
# Processing BUSI_division/masks/normal (18)_mask.png imgsz = 473 x 562
# Processed and stored at BUSI_division/labels/normal (18)_mask.txt imgsz = 473 x 562
# Processing BUSI_division/masks/normal (19)_mask.png imgsz = 566 x 660
# Processed and stored at BUSI_division/labels/normal (19)_mask.txt imgsz = 566 x 660
# Processing BUSI_division/masks/normal (2)_mask.png imgsz = 471 x 552
# Processed and stored at BUSI_division/labels/normal (2)_mask.txt imgsz = 471 x 552
# Processing BUSI_division/masks/normal (20)_mask.png imgsz = 687 x 851
# Processed and stored at BUSI_division/labels/normal (20)_mask.txt imgsz = 687 x 851
# Processing BUSI_division/masks/normal (21)_mask.png imgsz = 463 x 545
# Processed and stored at BUSI_division/labels/normal (21)_mask.txt imgsz = 463 x 545
# Processing BUSI_division/masks/normal (22)_mask.png imgsz = 470 x 552
# Processed and stored at BUSI_division/labels/normal (22)_mask.txt imgsz = 470 x 552
# Processing BUSI_division/masks/normal (23)_mask.png imgsz = 578 x 763
# Processed and stored at BUSI_division/labels/normal (23)_mask.txt imgsz = 578 x 763
# Processing BUSI_division/masks/normal (24)_mask.png imgsz = 573 x 626
# Processed and stored at BUSI_division/labels/normal (24)_mask.txt imgsz = 573 x 626
# Processing BUSI_division/masks/normal (25)_mask.png imgsz = 571 x 781
# Processed and stored at BUSI_division/labels/normal (25)_mask.txt imgsz = 571 x 781
# Processing BUSI_division/masks/normal (26)_mask.png imgsz = 475 x 738
# Processed and stored at BUSI_division/labels/normal (26)_mask.txt imgsz = 475 x 738
# Processing BUSI_division/masks/normal (27)_mask.png imgsz = 707 x 804
# Processed and stored at BUSI_division/labels/normal (27)_mask.txt imgsz = 707 x 804
# Processing BUSI_division/masks/normal (28)_mask.png imgsz = 619 x 761
# Processed and stored at BUSI_division/labels/normal (28)_mask.txt imgsz = 619 x 761
# Processing BUSI_division/masks/normal (29)_mask.png imgsz = 567 x 679
# Processed and stored at BUSI_division/labels/normal (29)_mask.txt imgsz = 567 x 679
# Processing BUSI_division/masks/normal (3)_mask.png imgsz = 465 x 554
# Processed and stored at BUSI_division/labels/normal (3)_mask.txt imgsz = 465 x 554
# Processing BUSI_division/masks/normal (30)_mask.png imgsz = 490 x 550
# Processed and stored at BUSI_division/labels/normal (30)_mask.txt imgsz = 490 x 550
# Processing BUSI_division/masks/normal (31)_mask.png imgsz = 473 x 547
# Processed and stored at BUSI_division/labels/normal (31)_mask.txt imgsz = 473 x 547
# Processing BUSI_division/masks/normal (32)_mask.png imgsz = 470 x 557
# Processed and stored at BUSI_division/labels/normal (32)_mask.txt imgsz = 470 x 557
# Processing BUSI_division/masks/normal (33)_mask.png imgsz = 587 x 777
# Processed and stored at BUSI_division/labels/normal (33)_mask.txt imgsz = 587 x 777
# Processing BUSI_division/masks/normal (34)_mask.png imgsz = 576 x 779
# Processed and stored at BUSI_division/labels/normal (34)_mask.txt imgsz = 576 x 779
# Processing BUSI_division/masks/normal (35)_mask.png imgsz = 688 x 616
# Processed and stored at BUSI_division/labels/normal (35)_mask.txt imgsz = 688 x 616
# Processing BUSI_division/masks/normal (36)_mask.png imgsz = 705 x 812
# Processed and stored at BUSI_division/labels/normal (36)_mask.txt imgsz = 705 x 812
# Processing BUSI_division/masks/normal (37)_mask.png imgsz = 709 x 816
# Processed and stored at BUSI_division/labels/normal (37)_mask.txt imgsz = 709 x 816
# Processing BUSI_division/masks/normal (38)_mask.png imgsz = 619 x 763
# Processed and stored at BUSI_division/labels/normal (38)_mask.txt imgsz = 619 x 763
# Processing BUSI_division/masks/normal (39)_mask.png imgsz = 618 x 757
# Processed and stored at BUSI_division/labels/normal (39)_mask.txt imgsz = 618 x 757
# Processing BUSI_division/masks/normal (4)_mask.png imgsz = 434 x 578
# Processed and stored at BUSI_division/labels/normal (4)_mask.txt imgsz = 434 x 578
# Processing BUSI_division/masks/normal (40)_mask.png imgsz = 598 x 763
# Processed and stored at BUSI_division/labels/normal (40)_mask.txt imgsz = 598 x 763
# Processing BUSI_division/masks/normal (41)_mask.png imgsz = 600 x 761
# Processed and stored at BUSI_division/labels/normal (41)_mask.txt imgsz = 600 x 761
# Processing BUSI_division/masks/normal (42)_mask.png imgsz = 611 x 763
# Processed and stored at BUSI_division/labels/normal (42)_mask.txt imgsz = 611 x 763
# Processing BUSI_division/masks/normal (43)_mask.png imgsz = 592 x 759
# Processed and stored at BUSI_division/labels/normal (43)_mask.txt imgsz = 592 x 759
# Processing BUSI_division/masks/normal (44)_mask.png imgsz = 618 x 761
# Processed and stored at BUSI_division/labels/normal (44)_mask.txt imgsz = 618 x 761
# Processing BUSI_division/masks/normal (45)_mask.png imgsz = 601 x 767
# Processed and stored at BUSI_division/labels/normal (45)_mask.txt imgsz = 601 x 767
# Processing BUSI_division/masks/normal (46)_mask.png imgsz = 310 x 393
# Processed and stored at BUSI_division/labels/normal (46)_mask.txt imgsz = 310 x 393
# Processing BUSI_division/masks/normal (47)_mask.png imgsz = 313 x 391
# Processed and stored at BUSI_division/labels/normal (47)_mask.txt imgsz = 313 x 391
# Processing BUSI_division/masks/normal (48)_mask.png imgsz = 312 x 392
# Processed and stored at BUSI_division/labels/normal (48)_mask.txt imgsz = 312 x 392
# Processing BUSI_division/masks/normal (49)_mask.png imgsz = 316 x 396
# Processed and stored at BUSI_division/labels/normal (49)_mask.txt imgsz = 316 x 396
# Processing BUSI_division/masks/normal (5)_mask.png imgsz = 573 x 765
# Processed and stored at BUSI_division/labels/normal (5)_mask.txt imgsz = 573 x 765
# Processing BUSI_division/masks/normal (50)_mask.png imgsz = 310 x 392
# Processed and stored at BUSI_division/labels/normal (50)_mask.txt imgsz = 310 x 392
# Processing BUSI_division/masks/normal (51)_mask.png imgsz = 490 x 554
# Processed and stored at BUSI_division/labels/normal (51)_mask.txt imgsz = 490 x 554
# Processing BUSI_division/masks/normal (52)_mask.png imgsz = 487 x 552
# Processed and stored at BUSI_division/labels/normal (52)_mask.txt imgsz = 487 x 552
# Processing BUSI_division/masks/normal (53)_mask.png imgsz = 648 x 757
# Processed and stored at BUSI_division/labels/normal (53)_mask.txt imgsz = 648 x 757
# Processing BUSI_division/masks/normal (54)_mask.png imgsz = 492 x 554
# Processed and stored at BUSI_division/labels/normal (54)_mask.txt imgsz = 492 x 554
# Processing BUSI_division/masks/normal (55)_mask.png imgsz = 491 x 557
# Processed and stored at BUSI_division/labels/normal (55)_mask.txt imgsz = 491 x 557
# Processing BUSI_division/masks/normal (56)_mask.png imgsz = 598 x 763
# Processed and stored at BUSI_division/labels/normal (56)_mask.txt imgsz = 598 x 763
# Processing BUSI_division/masks/normal (57)_mask.png imgsz = 490 x 548
# Processed and stored at BUSI_division/labels/normal (57)_mask.txt imgsz = 490 x 548
# Processing BUSI_division/masks/normal (58)_mask.png imgsz = 487 x 554
# Processed and stored at BUSI_division/labels/normal (58)_mask.txt imgsz = 487 x 554
# Processing BUSI_division/masks/normal (59)_mask.png imgsz = 621 x 765
# Processed and stored at BUSI_division/labels/normal (59)_mask.txt imgsz = 621 x 765
# Processing BUSI_division/masks/normal (6)_mask.png imgsz = 574 x 776
# Processed and stored at BUSI_division/labels/normal (6)_mask.txt imgsz = 574 x 776
# Processing BUSI_division/masks/normal (60)_mask.png imgsz = 486 x 552
# Processed and stored at BUSI_division/labels/normal (60)_mask.txt imgsz = 486 x 552
# Processing BUSI_division/masks/normal (61)_mask.png imgsz = 601 x 752
# Processed and stored at BUSI_division/labels/normal (61)_mask.txt imgsz = 601 x 752
# Processing BUSI_division/masks/normal (62)_mask.png imgsz = 598 x 763
# Processed and stored at BUSI_division/labels/normal (62)_mask.txt imgsz = 598 x 763
# Processing BUSI_division/masks/normal (63)_mask.png imgsz = 467 x 558
# Processed and stored at BUSI_division/labels/normal (63)_mask.txt imgsz = 467 x 558
# Processing BUSI_division/masks/normal (64)_mask.png imgsz = 470 x 558
# Processed and stored at BUSI_division/labels/normal (64)_mask.txt imgsz = 470 x 558
# Processing BUSI_division/masks/normal (65)_mask.png imgsz = 570 x 670
# Processed and stored at BUSI_division/labels/normal (65)_mask.txt imgsz = 570 x 670
# Processing BUSI_division/masks/normal (66)_mask.png imgsz = 468 x 561
# Processed and stored at BUSI_division/labels/normal (66)_mask.txt imgsz = 468 x 561
# Processing BUSI_division/masks/normal (67)_mask.png imgsz = 493 x 545
# Processed and stored at BUSI_division/labels/normal (67)_mask.txt imgsz = 493 x 545
# Processing BUSI_division/masks/normal (68)_mask.png imgsz = 488 x 558
# Processed and stored at BUSI_division/labels/normal (68)_mask.txt imgsz = 488 x 558
# Processing BUSI_division/masks/normal (69)_mask.png imgsz = 487 x 556
# Processed and stored at BUSI_division/labels/normal (69)_mask.txt imgsz = 487 x 556
# Processing BUSI_division/masks/normal (7)_mask.png imgsz = 585 x 770
# Processed and stored at BUSI_division/labels/normal (7)_mask.txt imgsz = 585 x 770
# Processing BUSI_division/masks/normal (70)_mask.png imgsz = 471 x 557
# Processed and stored at BUSI_division/labels/normal (70)_mask.txt imgsz = 471 x 557
# Processing BUSI_division/masks/normal (71)_mask.png imgsz = 470 x 547
# Processed and stored at BUSI_division/labels/normal (71)_mask.txt imgsz = 470 x 547
# Processing BUSI_division/masks/normal (72)_mask.png imgsz = 692 x 916
# Processed and stored at BUSI_division/labels/normal (72)_mask.txt imgsz = 692 x 916
# Processing BUSI_division/masks/normal (73)_mask.png imgsz = 474 x 509
# Processed and stored at BUSI_division/labels/normal (73)_mask.txt imgsz = 474 x 509
# Processing BUSI_division/masks/normal (74)_mask.png imgsz = 467 x 558
# Processed and stored at BUSI_division/labels/normal (74)_mask.txt imgsz = 467 x 558
# Processing BUSI_division/masks/normal (75)_mask.png imgsz = 467 x 556
# Processed and stored at BUSI_division/labels/normal (75)_mask.txt imgsz = 467 x 556
# Processing BUSI_division/masks/normal (76)_mask.png imgsz = 469 x 555
# Processed and stored at BUSI_division/labels/normal (76)_mask.txt imgsz = 469 x 555
# Processing BUSI_division/masks/normal (77)_mask.png imgsz = 471 x 560
# Processed and stored at BUSI_division/labels/normal (77)_mask.txt imgsz = 471 x 560
# Processing BUSI_division/masks/normal (78)_mask.png imgsz = 478 x 731
# Processed and stored at BUSI_division/labels/normal (78)_mask.txt imgsz = 478 x 731
# Processing BUSI_division/masks/normal (79)_mask.png imgsz = 471 x 703
# Processed and stored at BUSI_division/labels/normal (79)_mask.txt imgsz = 471 x 703
# Processing BUSI_division/masks/normal (8)_mask.png imgsz = 587 x 775
# Processed and stored at BUSI_division/labels/normal (8)_mask.txt imgsz = 587 x 775
# Processing BUSI_division/masks/normal (80)_mask.png imgsz = 470 x 562
# Processed and stored at BUSI_division/labels/normal (80)_mask.txt imgsz = 470 x 562
# Processing BUSI_division/masks/normal (81)_mask.png imgsz = 587 x 767
# Processed and stored at BUSI_division/labels/normal (81)_mask.txt imgsz = 587 x 767
# Processing BUSI_division/masks/normal (82)_mask.png imgsz = 468 x 560
# Processed and stored at BUSI_division/labels/normal (82)_mask.txt imgsz = 468 x 560
# Processing BUSI_division/masks/normal (83)_mask.png imgsz = 576 x 619
# Processed and stored at BUSI_division/labels/normal (83)_mask.txt imgsz = 576 x 619
# Processing BUSI_division/masks/normal (84)_mask.png imgsz = 477 x 509
# Processed and stored at BUSI_division/labels/normal (84)_mask.txt imgsz = 477 x 509
# Processing BUSI_division/masks/normal (85)_mask.png imgsz = 464 x 557
# Processed and stored at BUSI_division/labels/normal (85)_mask.txt imgsz = 464 x 557
# Processing BUSI_division/masks/normal (86)_mask.png imgsz = 469 x 552
# Processed and stored at BUSI_division/labels/normal (86)_mask.txt imgsz = 469 x 552
# Processing BUSI_division/masks/normal (87)_mask.png imgsz = 467 x 552
# Processed and stored at BUSI_division/labels/normal (87)_mask.txt imgsz = 467 x 552
# Processing BUSI_division/masks/normal (88)_mask.png imgsz = 463 x 560
# Processed and stored at BUSI_division/labels/normal (88)_mask.txt imgsz = 463 x 560
# Processing BUSI_division/masks/normal (89)_mask.png imgsz = 467 x 558
# Processed and stored at BUSI_division/labels/normal (89)_mask.txt imgsz = 467 x 558
# Processing BUSI_division/masks/normal (9)_mask.png imgsz = 491 x 495
# Processed and stored at BUSI_division/labels/normal (9)_mask.txt imgsz = 491 x 495
# Processing BUSI_division/masks/normal (90)_mask.png imgsz = 496 x 558
# Processed and stored at BUSI_division/labels/normal (90)_mask.txt imgsz = 496 x 558
# Processing BUSI_division/masks/normal (91)_mask.png imgsz = 493 x 558
# Processed and stored at BUSI_division/labels/normal (91)_mask.txt imgsz = 493 x 558
# Processing BUSI_division/masks/normal (92)_mask.png imgsz = 486 x 554
# Processed and stored at BUSI_division/labels/normal (92)_mask.txt imgsz = 486 x 554
# Processing BUSI_division/masks/normal (93)_mask.png imgsz = 578 x 770
# Processed and stored at BUSI_division/labels/normal (93)_mask.txt imgsz = 578 x 770
# Processing BUSI_division/masks/normal (94)_mask.png imgsz = 585 x 678
# Processed and stored at BUSI_division/labels/normal (94)_mask.txt imgsz = 585 x 678
# Processing BUSI_division/masks/normal (95)_mask.png imgsz = 582 x 693
# Processed and stored at BUSI_division/labels/normal (95)_mask.txt imgsz = 582 x 693
# Processing BUSI_division/masks/normal (96)_mask.png imgsz = 578 x 687
# Processed and stored at BUSI_division/labels/normal (96)_mask.txt imgsz = 578 x 687
# Processing BUSI_division/masks/normal (97)_mask.png imgsz = 470 x 560
# Processed and stored at BUSI_division/labels/normal (97)_mask.txt imgsz = 470 x 560
# Processing BUSI_division/masks/normal (98)_mask.png imgsz = 470 x 562
# Processed and stored at BUSI_division/labels/normal (98)_mask.txt imgsz = 470 x 562
# Processing BUSI_division/masks/normal (99)_mask.png imgsz = 468 x 556
# Processed and stored at BUSI_division/labels/normal (99)_mask.txt imgsz = 468 x 556
